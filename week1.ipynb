# %%
# codepath week one
'''def most_endangered(species_list):
    if species_list is None:
        return -1
    
    min_species = species_list[0]
    # min_val = species_list[0]["population"]
    for i in range(len(species_list)):
        # print(species_list[i])
        if species_list[i]["population"] == min_species["population"]:
            continue
        if species_list[i]["population"] < min_species["population"]:
            min_species = species_list[i]
        
    print(min_species["name"])



species_list = [
    {"name": "Amur Leopard",
     "habitat": "Temperate forests",
     "population": 84
    },
    {"name": "Javan Rhino",
     "habitat": "Tropical forests",
     "population": 10
    },
    {"name": "Vaquita",
     "habitat": "Marine",
     "population": 10
    }
]

print(most_endangered(species_list))'''


'''def count_endangered_species(endangered_species, observed_species):
    counter = 0
    for i in observed_species:
        if i in endangered_species:
            counter += 1

    return counter
        

endangered_species1 = "aA"
observed_species1 = "aAAbbbb"

endangered_species2 = "z"
observed_species2 = "ZZ"

print(count_endangered_species(endangered_species1, observed_species1)) 
print(count_endangered_species(endangered_species2, observed_species2))  '''

def navigate_research_station(station_layout, observations):  
    total = 0 
    curr_index = 0
    for i in observations:
        if i in station_layout:
            print(i)
            index = station_layout.find(i)
            print(index)
            total += abs(curr_index - index)
            index = curr_index

    return total
    

    # for index2, station2 in enumerate(observations):
        #print(station2)
      

station_layout1 = "pqrstuvwxyzabcdefghijklmno"
observations1 = "wildlife"

station_layout2 = "abcdefghijklmnopqrstuvwxyz"
observations2 = "cba"

print(navigate_research_station(station_layout1, observations1))  
print(navigate_research_station(station_layout2, observations2))
